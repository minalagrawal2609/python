# %% [markdown]
# <a href="https://colab.research.google.com/github/minalagrawal2609/python/blob/main/OOPS_TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# OOP TASK - 1  Library Book System:-
# STEP - 1 Create a class book with method __init__():-

class Book:
  library_name = "Python Academy Library"
  count = 0

  def __init__(self, title, author, year):
    self.title = title
    self.author = author
    self.year = year
    self.is_available = True
    Book.count += 1

# step - 2 Add a checkout() method:-
  def checkout(self):
    if self.is_available:
      print()
